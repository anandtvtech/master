# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
df.head()
df.shape
#df.info()
#df.describe(include='all').T

#sns.histplot(data=df, x='price');
#sns.histplot(data=df, x='price', color='orange');
plt.title('Histogram Chart');
plt.xlabel('Car Price');
plt.ylabel('Frequency');
plt.xlim(5000,35000);
#sns.histplot(data=df, x='price', binwidth=4000)
df.describe().T
bandwidth = 2*(16500-7775)/df.shape[0]**(1./3.)
print(bandwidth);
print(2*(16500-7775)/math.pow(df.shape[0],1/3))
noofbins = (df['price'].max()-df['price'].min())/bandwidth;
print(noofbins);
sns.histplot(data=df, x='price', binwidth = bandwidth)
#sns.histplot(data=df, x='price', bins = round(noofbins))
#sns.histplot(data=df, x='price', hue='body_style', kde=True)
g = sns.FacetGrid(df,col='body_style')
g.map(sns.histplot, 'price');
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 2978.9513599730403
# 2978.9513599730403
# 13.522208029729144

# %% [markdown]
# #BoxPlot

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
#sns.boxplot(data=df, x='horsepower',color='green')
#plt.title('Box plot');
#plt.xlabel('Horsepower');
#plt.ylabel('Frequency');
#sns.axes_style('whitegrid')
#plt.xlim(30,300);
plt.figure(figsize=(10,7))
sns.boxplot(data=df, x='body_style',y='price')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Bar Chart(countplot())

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
sns.countplot(data=df,x='body_style', hue='fuel_type')
plt.xticks(rotation=90)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# #LineChart(lineplot())

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
#df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
flights = sns.load_dataset("flights")
#sns.lineplot(data=flights,x='month', y='passengers',ci=False);
#sns.lineplot(data=flights,x='month',y='passengers',hue='year', style="year")
mri = sns.load_dataset('fmri');
sns.lineplot(data=mri, x="timepoint", y="signal", hue="region", style="region", ci=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #ScatterPlot(scatterplot());

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
#sns.scatterplot(data=df,x='engine_size', y='horsepower',hue="fuel_type", style="fuel_type");
#Positive Corelation
#sns.scatterplot(data=df,x='curb_weight', y='engine_size');
#No correlation
sns.scatterplot(data=df,x='bore',y="stroke")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# LinearModelPlot(lmplot())

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
sns.lmplot(data=df,x='curb_weight', y='horsepower',col="fuel_type", ci=True);
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# JointPlot(JointPlot())

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Week3/Automobile.csv')
#sns.jointplot(data=df,x='curb_weight', y='horsepower', kind='kde');
sns.jointplot(data=df,x='curb_weight', y='horsepower', kind='hex');
plt.colorbar()
#sns.jointplot(data=df,x='curb_weight', y='horsepower', kind='kde');
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
